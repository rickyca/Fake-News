# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set(font_scale=1)

# %%
real = pd.read_csv('parsed_data.csv')
fake = pd.read_csv('fake.csv')

# %%
fake.shape, real.shape
# Out:
# ((12999, 20), (2100, 20))

# %%
real.head()
# Out:
#                       author  comments country                        crawled  \
# 0              Stefanos Chen         0      US  2017-06-07T19:42:54.002+03:00
# 1           Associated Press         0      US  2017-06-07T19:48:14.000+03:00
# 2              Jason Douglas         0      US  2017-06-07T19:48:19.002+03:00
# 3  Jun 7th 2017 twitter icon         0      US  2017-06-07T19:49:45.013+03:00
# 4                  Kremilek2         0      US  2017-06-07T19:49:46.029+03:00
#
#    domain_rank language  likes  \
# 0        387.0  english    355
# 1        478.0  english    843
# 2        387.0  english     93
# 3       1742.0  english      0
# 4       1742.0  english      0
#
#                                           main_image  ord_in_thread  \
# 0  https://si.wsj.net/public/resources/images/BN-...              0
# 1  http://media2.s-nbcnews.com/i/newscms/2017_23/...              0
# 2  https://si.wsj.net/public/resources/images/BN-...              0
# 3  https://cdn.static-economist.com/assets/the-ec...              0
# 4  https://cdn.static-economist.com/sites/default...              1
#
#    participants_count                      published  replies_count  \
# 0                   1  2017-06-07T19:42:54.002+03:00              0
# 1                   0  2017-06-07T19:48:14.000+03:00              0
# 2                   1  2017-06-07T18:28:00.000+03:00              0
# 3                   1  2017-06-07T08:00:00.000+03:00              0
# 4                   2  2017-06-01T22:45:00.000+03:00              1
#
#          section_title  shares           site  spam_score  \
# 0   WSJ.com: Lifestyle     355        wsj.com       0.000
# 1                  NaN     843    nbcnews.com       0.231
# 2  WSJ.com: World News      93        wsj.com       0.000
# 3  Computer Technology       0  economist.com       0.000
# 4  Computer Technology       0  economist.com       0.000
#
#                                                 text  \
# 0  A just-finished 12,000-square-foot, modernist ...
# 1  SANDY, Utah — Utah investigators and stunned r...
# 2  Britons go to the polls on Thursday to cast th...
# 3  Companies are striving to control an evolving ...
# 4  I guess that it is not so much surprising that...
#
#                                                title    type  \
# 0    Glassy Los Angeles Home Seeks $44 Million - WSJ  normal
# 1  Sandy, Utah Shooting: Mom, Young Son Dead Afte...  normal
# 2  U.K. Election: Testing Times for Pollsters Who...  normal
# 3               Babbage: Podcast: Battle of the maps  normal
# 4  Technology governance: China’s new cyber-secur...  normal
#
#                                        uuid
# 0  1677f40aafa459dc039b7f5805b664d2a9765b44
# 1  b6cdc79d109fcd6b1e5d88d0e6542d88ff6ed888
# 2  3365bcc27dce4bbd109ac26fa1e86141202a5a99
# 3  68e9e96232d8c8bad016e98ceca7ac9299a33bef
# 4  55c5d1ef7f18fbe238a23c2f38ef7b4888581f2c
